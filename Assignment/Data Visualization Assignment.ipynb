# %% [markdown]
# # Data Analysis and Machine Learning Using Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Visualization Assignment

# %% [markdown]
# ### Submission Date & Time : 21st June 2020 & 15:00

# %% [markdown]
# ## Q.1
# - Import all modules required for Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Q.2
# - Plot a Sine Wave with color code with "black" color and style as dashdot, also mark "x" and "y" label and give a suitable title to it

# %%
x = np.arange(0,20,0.1)
y = np.sin(x)

# %%
plt.plot(x,y,color = "black" , linestyle = '-.')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Sine Waveform")
# Out:
# Text(0.5, 1.0, 'Sine Waveform')

# %% [markdown]
# ## Q.3
# - Plot a line curve with list=[2,3,4,5], use linestyle and color together for the graph and marker style as "Rotated Hexagon Marker"

# %%
plt.plot([2,3,4,5] ,'g:',marker = 'h' )

# %% [markdown]
# ## Q.4
# ![image.png](attachment:image.png)
# -Plot Stacked Bar Graph for the above data.
#     - Use proper colors and x and y label for the graph
#     - Use legend positioned at upper right corner
#     - Also mark xticks with an angle of 90 Degree

# %%
Store = ['Clothing' , 'Equipment' ,'Accessories']
Delhi = [82 , 48 , 15]
Mumbai = [78 , 31 , 20]
Chennai = [48 , 51 , 14]
Kolkata = [46 , 29 , 13]
Hyderabad = [39 ,18, 9]
fig = plt.figure(figsize = (5 ,3))
ax = fig.add_axes([0 , 0 , 1 , 1])

ax.legend(loc='upper right')
plt.bar(Store , Delhi , label='Delhi')
plt.bar(Store , Mumbai ,label='Mumbai')
plt.bar(Store , Chennai , label = 'Chennai')
plt.bar(Store , Kolkata , label = 'Kolkata')
plt.bar(Store , Hyderabad , label = 'Hyderabad')
plt.xlabel("Stores")

plt.xticks(rotation=90)
# Out:
# No handles with labels found to put in legend.
# ([0, 1, 2], <a list of 3 Text major ticklabel objects>)

# %% [markdown]
# ## Q.5 For Titanic Dataset
# - Load Dataset using Seaborn
# - Plot a Bar Graph of Survival of Passenger against the Passenger Class.
# - Use proper "hue" attribute, and palette color. Mark 'x' and 'y' label with proper title.
# - Use legend located at upper left corner

# %%
titanic = sns.load_dataset('titanic')
fig = plt.figure(figsize = (5 ,3))
ax = fig.add_axes([0 , 0 , 1 , 1])
gp = list(titanic.groupby('class').survived.count())
plt.bar(['First' , 'Second' , 'Third'] , gp )
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Q.6 For Tips Dataset
# - Load the Dataset Using Seaborn
# - Plot the Horizontal Distribution Graph on Total Bill with color as Green
# - Mark proper 'x' and 'y' label and give a suitable title

# %%
tips = sns.load_dataset('tips')
fig = plt.figure(figsize = (5 ,3))
ax = fig.add_axes([0 , 0 , 1 , 1])
sns.distplot(tips['total_bill'] , kde = False , vertical = True , color = 'green')
ax.set(xlabel = 'Dollars' , ylabel = 'Total_Bill' , title = 'Horizontal_Distribution_Graph')
# Out:
# [Text(0, 0.5, 'Total_Bill'),
#  Text(0.5, 0, 'Dollars'),
#  Text(0.5, 1.0, 'Horizontal_Distribution_Graph')]

# %% [markdown]
# # Q.7
# - Also plot the KDE Graph for the above data

# %%
sns.kdeplot(tips['total_bill'])

# %% [markdown]
# ## Q.8 For Cancer Dataset
# - Load the data with the help of Matplotlib (Dataset Provided)
# - Print the first 10 data of the whole dataset
# - Plot Box Plot with column 'texture_mean' , separated by column 'diagnosis'

# %%
df2 = pd.read_csv("D:/Titanic Dataset/Cancer.csv")
df2.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# 2          0.10960           0.15990         0.19740              0.12790
# 3          0.14250           0.28390         0.24140              0.10520
# 4          0.10030           0.13280         0.19800              0.10430
# 5          0.12780           0.17000         0.15780              0.08089
# 6          0.09463           0.10900         0.11270              0.07400
# 7          0.11890           0.16450         0.09366              0.05985
# 8          0.12730           0.19320         0.18590              0.09353
# 9          0.11860           0.23960         0.22730              0.08543
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
# 5  ...         15.47          23.75           103.40       741.6
# 6  ...         22.88          27.66           153.20      1606.0
# 7  ...         17.06          28.14           110.60       897.0
# 8  ...         15.49          30.73           106.20       739.3
# 9  ...         15.09          40.68            97.65       711.4
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
# 6            0.1442             0.2576           0.3784                0.1932
# 7            0.1654             0.3682           0.2678                0.1556
# 8            0.1703             0.5401           0.5390                0.2060
# 9            0.1853             1.0580           1.1050                0.2210
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
# 5          0.3985                  0.12440
# 6          0.3063                  0.08368
# 7          0.3196                  0.11510
# 8          0.4378                  0.10720
# 9          0.4366                  0.20750
#
# [10 rows x 32 columns]

# %%
fig = plt.figure(figsize = (5 ,3))
ax = fig.add_axes([0 , 0 , 1 , 1])
sns.boxplot(df2.diagnosis , df2.texture_mean)

# %% [markdown]
# ## Q.9
# ![image.png](attachment:image.png)
#
# - Plot the Pie Chart for the two colums with some explode for the country "India"  and proper shadow

# %%
fig = plt.figure(figsize = (5 ,3))
ax = fig.add_axes([0 , 0 , 1 , 1])
country = ['United States' , 'Great Britain' , 'India' , 'Russia' , 'Germany']
medal = [46 , 27 , 26 , 19 , 17]
explode = (0,0,0.1,0,0)
ax.pie(medal , explode = explode , labels = country , autopct='%1.1f%%' , shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2a6afb7c2c8>,
#   <matplotlib.patches.Wedge at 0x2a6afb81308>,
#   <matplotlib.patches.Wedge at 0x2a6afb87808>,
#   <matplotlib.patches.Wedge at 0x2a6afb8fe08>,
#   <matplotlib.patches.Wedge at 0x2a6afb9a848>],
#  [Text(0.5276844259140197, 0.9651679370181085, 'United States'),
#   Text(-1.0246277154553132, 0.40017251869765635, 'Great Britain'),
#   Text(-0.7819886644855274, -0.9102163086959834, 'India'),
#   Text(0.3641697549943344, -1.037969358674603, 'Russia'),
#   Text(1.015038685557071, -0.4239062005002681, 'Germany')],
#  [Text(0.28782786868037435, 0.5264552383735137, '34.1%'),
#   Text(-0.558887844793807, 0.21827591928963072, '20.0%'),
#   Text(-0.4561600542832243, -0.5309595134059901, '19.3%'),
#   Text(0.19863804817872782, -0.5661651047316016, '14.1%'),
#   Text(0.5536574648493114, -0.23122156390923712, '12.6%')])

# %% [markdown]
# ## Q.10 For Tips Dataset
# - Load the dataset using seaborn
# - Draw the Strip Plot between 'total bill' and 'day'
# - Rotate xticks with an angle of 45 Degree

# %%
tips = sns.load_dataset('tips')
sns.stripplot(x = 'day' , y = 'total_bill' , data = tips , split = True )
plt.xticks(rotation=45)
# Out:
# C:\Users\PRANJAL SHAHI\anaconda3\lib\site-packages\seaborn\categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)
